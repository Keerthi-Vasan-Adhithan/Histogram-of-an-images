# %% [markdown]
# Histogram for Bright Image

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\sec\anaconda3\envs\dip2\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the color image
image = cv2.imread('Bright.tif')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])

# Apply histogram equalization
equalized_image = cv2.equalizeHist(gray_image)

# Plotting the original grayscale image, equalized image, and histograms
plt.figure(figsize=(10, 7))

# Show original grayscale image
plt.subplot(2, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')

# Show equalized grayscale image
plt.subplot(2, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

# Plot histogram of the original grayscale image
plt.subplot(2, 2, 3)
plt.plot(hist_original, color='black')
plt.title('Original Histogram')
plt.xlim([0, 256])

# Plot histogram of the equalized image
plt.subplot(2, 2, 4)
hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
plt.plot(hist_equalized, color='black')
plt.title('Equalized Histogram')
plt.xlim([0, 256])

plt.tight_layout()
plt.show()
# Out:
# Error occurred: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'equalized_image' is not defined
# Error occurred: name 'hist_original' is not defined
# Error occurred: name 'equalized_image' is not defined
# Error occurred: name 'hist_equalized' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 9, in <module>
#     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# cv2.error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 11, in <module>
#     hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 14, in <module>
#     equalized_image = cv2.equalizeHist(gray_image)
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 21, in <module>
#     plt.imshow(gray_image, cmap='gray')
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 27, in <module>
#     plt.imshow(equalized_image, cmap='gray')
# NameError: name 'equalized_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 33, in <module>
#     plt.plot(hist_original, color='black')
# NameError: name 'hist_original' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 39, in <module>
#     hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
# NameError: name 'equalized_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\2715078535.py", line 40, in <module>
#     plt.plot(hist_equalized, color='black')
# NameError: name 'hist_equalized' is not defined

# %% [markdown]
# Dark Image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the color image
image = cv2.imread('Dark.tif')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply histogram equalization
equalized_image = cv2.equalizeHist(gray_image)

# Plotting the original grayscale image, equalized image, and histograms
plt.figure(figsize=(10, 7))

# Show original grayscale image
plt.subplot(2, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')

# Show equalized grayscale image
plt.subplot(2, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

# Plot histogram of the original grayscale image
plt.subplot(2, 2, 3)
hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
plt.plot(hist_original, color='black')
plt.title('Original Histogram')
plt.xlim([0, 256])

# Plot histogram of the equalized image
plt.subplot(2, 2, 4)
hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
plt.plot(hist_equalized, color='black')
plt.title('Equalized Histogram')
plt.xlim([0, 256])

plt.tight_layout()
plt.show()
# Out:
# Error occurred: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'equalized_image' is not defined
# Error occurred: name 'gray_image' is not defined
# Error occurred: name 'hist_original' is not defined
# Error occurred: name 'equalized_image' is not defined
# Error occurred: name 'hist_equalized' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 9, in <module>
#     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# cv2.error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 12, in <module>
#     equalized_image = cv2.equalizeHist(gray_image)
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 19, in <module>
#     plt.imshow(gray_image, cmap='gray')
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 25, in <module>
#     plt.imshow(equalized_image, cmap='gray')
# NameError: name 'equalized_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 31, in <module>
#     hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
# NameError: name 'gray_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 32, in <module>
#     plt.plot(hist_original, color='black')
# NameError: name 'hist_original' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 38, in <module>
#     hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])
# NameError: name 'equalized_image' is not defined
# Traceback (most recent call last):
#   File "C:\Users\SEC\anaconda3\envs\dip2\lib\site-packages\IPython\core\interactiveshell.py", line 3528, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SEC\AppData\Local\Temp\ipykernel_13852\177040399.py", line 39, in <module>
#     plt.plot(hist_equalized, color='black')
# NameError: name 'hist_equalized' is not defined
